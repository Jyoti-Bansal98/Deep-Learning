# %% [markdown]
# ### Contextual Embeddings (THIS is the real NLP → Transformer bridge)

# %% [raw]
# Transformer says:  “Word ka meaning sentence ke baaki words se decide hoga”
#
# learning (AI context) ≠ learning (human habit context)
# Same word, different vector
#
# Transformer internally asks:  “Is sentence me kaunsa word important hai?”
# That weighted importance → embedding change.
#
# That’s it.
# Attention = importance weighting, nothing magical.

# %%
from sentence_transformers import SentenceTransformer

# %%
model = SentenceTransformer("all-MiniLM-L6-v2")
# Out:
# Loading weights:   0%|          | 0/103 [00:00<?, ?it/s]
# BertModel LOAD REPORT from: sentence-transformers/all-MiniLM-L6-v2
# Key                     | Status     |  |
# ------------------------+------------+--+-
# embeddings.position_ids | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# ...

# %%
sent1 = "I am learning AI"
sent2 = "The model is learning patterns from data"

# %%
emb1 = model.encode(sent1)
emb2 = model.encode(sent2)

# %%
from sklearn.metrics.pairwise import cosine_similarity
cosine_similarity([emb1], [emb2])
# Out:
# array([[0.43665874]], dtype=float32)
