# %% [raw]
# Embedding hoti kya hai? (human-level intuition)
# Socho tumhare paas ek radar hai jo meaning detect karta hai.
#
# Har sentence → ek long list of numbers
# (usually 384, 768, 1024 numbers)
#
# Example (fake, small numbers):
# "I love cats"
# → [0.12, -0.44, 0.91, 0.03, ...]
# "I like kittens"
# → [0.11, -0.40, 0.89, 0.05, ...]
#
# Numbers different hain,
# pattern similar hai → meaning similar.

# %% [raw]
# Important point
#
# Embedding:
# word ka meaning nahi
# sentence ka meaning capture karti hai
# context ke saath
#
# Isliye:
# “bank” (river)
# “bank” (money)
# different embeddings bana sakta hai.

# %% [raw]
# Model meaning compare kaise karta hai?
# Using cosine similarity.
#
# Intuition:
# vectors same direction → similar meaning
# opposite direction → different meaning
#
# Score range:
# 1.0 → almost same
# 0.0 → unrelated
# -1.0 → opposite (rare in text)

# %%
pip install sentence-transformers
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from sentence_transformers import SentenceTransformer

model = SentenceTransformer("all-MiniLM-L6-v2")
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# File ~\AppData\Roaming\Python\Python313\site-packages\transformers\utils\import_utils.py:2045, in _LazyModule.__getattr__(self, name)
#    2044 try:
# -> 2045     module = self._get_module(self._class_to_module[name])
#    2046     value = getattr(module, name)
#
# File ~\AppData\Roaming\Python\Python313\site-packages\transformers\utils\import_utils.py:2239, in _LazyModule._get_module(self, module_name)
#    2238 except Exception as e:
# -> 2239     raise e
#
# File ~\AppData\Roaming\Python\Python313\site-packages\transformers\utils\import_utils.py:2237, in _LazyModule._get_module(self, module_name)
#    2236 try:
# -> 2237     return importlib.import_module("." + module_name, self.__name__)
#    2238 except Exception as e:
#
# File ~\anaconda3\Lib\importlib\__init__.py:88, in import_module(name, package)
# ...

# %%
sentences = [
    "I love learning artificial intelligence",
    "I enjoy studying AI and machine learning",
    "Cats are very cute animals",
    "I hate wasting time",
    "Artificial intelligence is fascinating"
]

# %%
embeddings = model.encode(sentences)
embeddings

# %%
print(embeddings.shape)

# %% [raw]
# 5 sentences
# each → 384 numbers
# ye hi vectors baad me vector DB me jaayenge

# %%
from sklearn.metrics.pairwise import cosine_similarity

similarity_matrix = cosine_similarity(embeddings)
print(similarity_matrix)

# %% [raw]
# Sentence 1 ↔ 2 → high similarity
# Sentence 1 ↔ 5 → high
# Sentence 1 ↔ 3 → low
#
# 👉 Model ne meaning samjha.
# No rules.
# No keywords.
# Just numbers.

# %%
sentences = [
    "I am preparing for a GenAI internship",
    "I want to build a career in artificial intelligence",
    "I am feeling sleepy today",
    "Pizza is my favorite food"
]

# %%
embeddings = model.encode(sentences)

# %%
similarity_matrix = cosine_similarity(embeddings)
print(similarity_matrix)

# %%
sentences = [
    "I love myself",
    "I will go on solo date",
    "I love my mom",
    "I am scared of ghosts"
]

# %%
embeddings = model.encode(sentences)

# %%
similarity_matrix = cosine_similarity(embeddings)
print(similarity_matrix)
