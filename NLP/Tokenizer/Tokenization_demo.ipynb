# %%
# !pip install transformers torch sentencepiece
# Out:
# ...
#    ---------------------------------------- 0.0/1.1 MB ? eta -:--:--
#    ------------------- -------------------- 0.5/1.1 MB 3.4 MB/s eta 0:00:01
#    ---------------------------------------- 1.1/1.1 MB 3.1 MB/s eta 0:00:00
# ...

# %%
from transformers import AutoTokenizer

tokenizer = AutoTokenizer.from_pretrained("bert-base-uncased")
# Out:
# config.json:   0%|          | 0.00/570 [00:00<?, ?B/s]
# C:\Users\Jyoti Bansal\AppData\Roaming\Python\Python313\site-packages\huggingface_hub\file_download.py:130: UserWarning: `huggingface_hub` cache-system uses symlinks by default to efficiently store duplicated files but your machine does not support them in C:\Users\Jyoti Bansal\.cache\huggingface\hub\models--bert-base-uncased. Caching files will still work but in a degraded version that might require more space on your disk. This warning can be disabled by setting the `HF_HUB_DISABLE_SYMLINKS_WARNING` environment variable. For more details, see https://huggingface.co/docs/huggingface_hub/how-to-cache#limitations.
# To support symlinks on Windows, you either need to activate Developer Mode or to run Python as an administrator. In order to activate developer mode, see this article: https://docs.microsoft.com/en-us/windows/apps/get-started/enable-your-device-for-development
#   warnings.warn(message)
# ...

# %%
text = "I want to learn GenAI properly"

# %%
tokens = tokenizer.tokenize(text)
print(tokens)
# Out:
# ['i', 'want', 'to', 'learn', 'gen', '##ai', 'properly']

# %% [raw]
# Question: “GenAI” do tokens me kyu toota?
#
# Answer: tokenizer ko “GenAI” word dictionary me nahi mila
# toh usne usko tod diya:
# - gen
# - ai (## means continuation)
#
# 👉 Isi wajah se prompt me unusual words break hote hain.

# %%
token_ids = tokenizer.convert_tokens_to_ids(tokens)
print(token_ids)
# Out:
# [1045, 2215, 2000, 4553, 8991, 4886, 7919]

# %%
len(tokens)
# Out:
# 7

# %%
text = 'i m loving learning genai'

# %%
tokens = tokenizer.tokenize(text)
print(tokens)
# Out:
# ['i', 'm', 'loving', 'learning', 'gen', '##ai']

# %%
token_ids = tokenizer.convert_tokens_to_ids(tokens)
print(token_ids)
# Out:
# [1045, 1049, 8295, 4083, 8991, 4886]

# %%
len(tokens)
# Out:
# 6

# %%
text = 'yaar sab kuch bohot messy hai kuch samajh nhi aa rha'

# %%
tokens = tokenizer.tokenize(text)
print(tokens)
# Out:
# ['ya', '##ar', 'sa', '##b', 'ku', '##ch', 'bo', '##hot', 'messy', 'hai', 'ku', '##ch', 'sam', '##aj', '##h', 'nh', '##i', 'aa', 'r', '##ha']

# %%
token_ids = tokenizer.convert_tokens_to_ids(tokens)
print(token_ids)
# Out:
# [8038, 2906, 7842, 2497, 13970, 2818, 8945, 12326, 18307, 15030, 13970, 2818, 3520, 13006, 2232, 18699, 2072, 9779, 1054, 3270]

# %%
len(tokens)
# Out:
# 20

# %%
text = 'shamita and siddharth love eachother soo much'

# %%
tokens = tokenizer.tokenize(text)
print(tokens)
# Out:
# ['sham', '##ita', 'and', 'sid', '##dhar', '##th', 'love', 'each', '##oth', '##er', 'soo', 'much']

# %%
token_ids = tokenizer.convert_tokens_to_ids(tokens)
print(token_ids)
# Out:
# [25850, 6590, 1998, 15765, 25632, 2705, 2293, 2169, 14573, 2121, 17111, 2172]

# %%
len(tokens)
# Out:
# 12

# %%
text = 'pata nhi kha khase aa jate hai'

# %%
tokens = tokenizer.tokenize(text)
print(tokens)
# Out:
# ['pat', '##a', 'nh', '##i', 'k', '##ha', 'k', '##has', '##e', 'aa', 'ja', '##te', 'hai']

# %%
len(tokens)
# Out:
# 13
